# %%
import pandas as pd 

try: 
    df = pd.read_csv("../../app/recommendations.csv", delimiter=";", encoding="utf-8")
    print(df.head())  # Vérifier les premières lignes
except Exception as e:
    print(f"Erreur de lecture du fichier CSV : {e}")
# Out:
#                   Question,Response,Document Content
# 0  je veux liquide avec cassis,"Pour un e-liquide...
# 1  1. **Cassis Frais Cirkus VDLV** : Ce e-liquide...
# 2  2. **Cassis Framboise Bleue 200ml Biggy Bear**...
# 3  Ces deux options sont fabriquées en France et ...
# 4  url: https://www.aromes-et-liquides.fr/e-liqui...
